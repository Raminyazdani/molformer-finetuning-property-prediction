# %% [markdown]
# # MolFormer Fine-tuning: Masked Language Modeling and Regression
#
# This notebook demonstrates fine-tuning MolFormer for molecular property prediction.

# %%
# Import libraries
import torch
from transformers import AutoTokenizer, AutoModelForMaskedLM
from datasets import load_dataset
import pandas as pd
import numpy as np

# %%
# Load dataset
dataset = load_dataset('MoleculeNet/lipophilicity')
print(f'Dataset loaded: {len(dataset["train"])} training samples')

# %%
# Load pre-trained MolFormer
# Fixed: Corrected typo in model path
model_path = './models/mlm_finetuned_molformer'  # Fixed: was 'mlm_finetuend_molformer'
print('Model will be loaded from:', model_path)

# %% [markdown]
# ## Next Steps
#
# - Implement tokenization
# - Set up training loop
# - Add regression head
# - Generate predictions
